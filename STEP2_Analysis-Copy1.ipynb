# %% [markdown]
# # 1. Import Packages

# %%
import sys, os
import pandas as pd
import numpy as np
from datetime import timedelta
import datetime
from timer import date_to_date, time_to_delta

# %% [markdown]
# # 2. Load Files
# 데이터셋이 저장되어 있는 nielsen_data 폴더를 path 변수로 지정, 해당경로 밑에 있는 파일명을 불러와 files 변수에 list 형태로 저장

# %%
path = 'nielsen_data_new_20170328/T1'
files = os.listdir(path)

# %% [markdown]
# 각각의 텍스트 파일을 읽어와 text에 line-by-line으로 저장

# %%
text = []
for file in files:
    print('Reading %s' % file)
    with open(os.path.join(path, file), 'rb') as f:
        text += f.readlines()
print("\n========%s logs are loaded========\n" % str(len(text)))
# Out:
# Reading 20150817.txt
# Reading 20150818.txt
# Reading 20150819.txt
# Reading 20150820.txt
# Reading 20150821.txt
# Reading 20150822.txt
# Reading 20150823.txt
# Reading 20150824.txt
# Reading 20150825.txt
# Reading 20150826.txt
# Reading 20150827.txt
# Reading 20150828.txt
# Reading 20150829.txt
# Reading 20150830.txt
#
# ========908408 logs are loaded========

# %% [markdown]
# # 3. Data Preprocessing
# 각 line(log)의 encoding을 변환('euc-kr' -> 'utf-8'), 각 line 끝에 new line을 strip 함수로 제거하고 구분자인 '^'로 split하여 parsed에 저장

# %%
parsed = list(map(lambda line: line.decode('euc-kr').strip('\r\n').split('^'), text))
print('Every line is successfully parsed.')
# Out:
# Every line is successfully parsed.

# %%
pd.to_datetime(parsed[0][0])
# list(map(lambda x: datetime.time(int(x[0])) + datetime.timedelta(int(x[10]), '%H%M%S'), sample))
print(datetime.datetime(2016, 8,23)+datetime.timedelta(hours = 26, minutes = 43, seconds = 11))
# Out:
# 2016-08-24 02:43:11

# %% [markdown]
# data frame에서 사용할 column 이름(제공받은 엑셀 파일에서 복사)을 split 하여 list 형태로 cols에 저장

# %%
cols = "일자	패널가구ID	개인ID	가중치	성별	연령	직업	학력	소득	채널	시청시작시간	시청종료시간	프로그램시청시간	프로그램명	프로그램편성시작시간	프로그램편성종료시간	프로그램장르"
cols = cols.split()

# %% [markdown]
# parsed에 저장된 로그들을 data로, cols에 저장된 이름을 columns으로 하는 pandas data frame 생성 : raw_df

# %%
raw_df = pd.DataFrame(data=parsed, columns=cols)

# %% [markdown]
# ## 3.1. Convert string to datetime
# raw_df에 string으로 표현되어 있는 각종 시간에 관련된 column을 시간 연산이 가능하도록 type 변경 함수 작성
#
# date_to_date: '20160823'의 형태로 되어 있는 데이터를 2016년 8월 23일로 변경
#
# time_to_delta: 24시 이후는 다음날로 처리하기 위하여 timedelta의 형태('265745'의 형태로 되어 있는 데이터를 26시간 57분 45초)로 변경

# %%
def date_to_date(date):
    year, month, day = map(int, [date[0:4], date[4:6], date[6:8]])
    return datetime.datetime(year, month, day)

def time_to_delta(time):
    hours, minutes, seconds = map(int, [time[0:2], time[2:4], time[4:6]])
    return datetime.timedelta(hours=hours, minutes=minutes, seconds=seconds)

# print('===== Test Code =====')
# d = input('Type original date in string(YYYYMMDD) : ')
# t = input('Type original time in string(HHMMSS) : ')
# print('Typed string \'%s\' and \'%s\' is converted to %s' % (d, t, date_to_date(d) + time_to_delta(t)))
# print('===== Test End =====')

# %% [markdown]
# 작성한 함수를 활용하여 시청시작/종료시간 및 프로그램시작/종료시간을 일자와 합산하여 별도의 column 생성

# %%
raw_df['view_start'] = raw_df.일자.apply(date_to_date) + raw_df.시청시작시간.apply(time_to_delta)
raw_df['view_end'] = raw_df.일자.apply(date_to_date) + raw_df.시청종료시간.apply(time_to_delta)
# raw_df['program_start'] = raw_df.일자.apply(date_to_date) + raw_df.프로그램편성시작시간.apply(time_to_delta)
# raw_df['program_end'] = raw_df.일자.apply(date_to_date) + raw_df.프로그램편성종료시간.apply(time_to_delta)

# %% [markdown]
# 프로그램시청시간(duration) = 시청종료시간(view_end) - 시청시작시간(view_start)

# %%
raw_df['duration'] = raw_df.view_end - raw_df.view_start + timedelta(seconds = 1)
# raw_df['duration_sec'] = raw_df.duration.apply(timedelta.total_seconds)

# %% [markdown]
# ## 3.2. Deal with NaN
# 데이터가 누락된 빈 문자열('')을 numpy의 nan으로 설정하여 nan이 포함된 행(axis = 0)을 drop

# %%
tidy_df = raw_df.replace('', np.nan, regex=True).dropna(axis = 0)
# tidy_df.프로그램시청시간 = tidy_df.프로그램시청시간.astype(int)

# %% [markdown]
# 전처리 과정이 완료된 데이터 상위 10행 예시

# %%
# tidy_df.head(10)
tidy_df.ix[(tidy_df.일자 == '20150817') & (tidy_df.패널가구ID == '1401639') & (tidy_df.개인ID == 'aa'), 9:]
# Out:
#         채널  시청시작시간  시청종료시간 프로그램시청시간                 프로그램명 프로그램편성시작시간  \
# 0        2  080900  082359      883                  인간극장     075006
# 2        2  120200  120259       60               KBS뉴스12     115948
# 3        2  120800  120959      120               KBS뉴스12     115948
# 4        2  124200  124359      120               KBS뉴스12     115948
# 5        2  132900  133059      120             역사저널그날<재>     125918
# 6        2  135000  135259      178               별별가족<재>     134846
# 8        2  143400  143559      120             한국인의밥상<재>     140030
# 10       2  160500  160759      180              KBS오늘의경제     155901
# 12       2  163800  163959      120           걸어서세계속으로<재>     160927
# 14       3  082400  083459      660            KBS8아침뉴스타임     075738
# 16       3  083800  083859       60            KBS8아침뉴스타임     075738
# 18       3  093000  093059       60        TV소설(그래도푸르른날에)     085851
# 20       3  093300  093559      180        TV소설(그래도푸르른날에)     085851
# 22       3  122200  122359      120           걸어서세계속으로<재>     120221
# 23       3  131400  131559      120           시간을달리는TV<재>     125637
# 29       4  223000  223259      180            창사특별기획(화정)     215907
# 44      11  144100  145359      780     벤자민버튼의시간은거꾸로간다-1부     141219
# 46      11  152300  152759      300     벤자민버튼의시간은거꾸로간다-1부     141219
# 48      11  154500  154659      120     벤자민버튼의시간은거꾸로간다-1부     141219
# 50      11  164400  164559      120     벤자민버튼의시간은거꾸로간다-2부     155228
# 206     135128  015005015 2015-08-17 13:27:00 2015-08-17 13:28:59  00:02:00
# 210     233128  015005015 2015-08-17 22:28:00 2015-08-17 22:29:59  00:02:00
# 212     233128  015005015 2015-08-17 22:44:00 2015-08-17 22:45:59  00:02:00
# 214     233128  015005015 2015-08-17 22:47:00 2015-08-17 22:49:59  00:03:00
# 216     120219  005005088 2015-08-17 11:47:00 2015-08-17 11:57:59  00:11:00
# 218     130137  020020000 2015-08-17 12:57:00 2015-08-17 12:59:59  00:03:00
# 219     140049  005010010 2015-08-17 13:24:00 2015-08-17 13:26:59  00:03:00
# 220     140049  005010010 2015-08-17 13:47:00 2015-08-17 13:49:59  00:03:00
# 222     150210  005005088 2015-08-17 14:54:00 2015-08-17 14:56:59  00:03:00
# 224     154156  010010015 2015-08-17 15:37:00 2015-08-17 15:38:59  00:02:00
# 226     173807  005005088 2015-08-17 17:04:00 2015-08-17 17:06:59  00:03:00
# 228     173807  005005088 2015-08-17 17:10:00 2015-08-17 17:12:59  00:03:00
# 231     230554  015099045 2015-08-17 22:22:00 2015-08-17 22:23:59  00:02:00
# 233     230554  015099045 2015-08-17 22:35:00 2015-08-17 22:41:59  00:07:00
# 235     084553  005005010 2015-08-17 08:42:00 2015-08-17 08:52:59  00:11:00
# 237     094201  005005010 2015-08-17 08:42:00 2015-08-17 08:52:59  00:11:00
# 239     124116  005005010 2015-08-17 11:58:00 2015-08-17 11:59:59  00:02:00
# 243     224910  035005005 2015-08-17 22:14:00 2015-08-17 22:15:59  00:02:00
#
# [100 rows x 11 columns]

# %%
# t = tidy_df.groupby(['일자', '패널가구ID', '개인ID']).시청시작시간.apply(list).reset_index(name = 't')

# %%
# cont = lambda row: row.shift(1) == row

# %%
# tidy_df.groupby(['일자', '패널가구ID', '개인ID']).시청시작시간 == 
tidy_df.groupby(['일자', '패널가구ID', '개인ID']).get_group['20160817']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-e272cfa2445c> in <module>()
#       1 # tidy_df.groupby(['일자', '패널가구ID', '개인ID']).시청시작시간 ==
# ----> 2 tidy_df.groupby(['일자']).get_group['20160817']
#
# TypeError: 'method' object is not subscriptable

# %%
# for key in t.groups.keys():
#     print(t.groups[key])
timedelta(23, 17, 59) - timedelta(21, 54, 0)
# Out:
# datetime.timedelta(1, 86363, 59)

# %% [markdown]
# # 4. Analysis

# %% [markdown]
# ## 4.1. Daily program repertoire of each person

# %% [markdown]
# tidy_df 데이터 프레임을 일자별, 개인별로 각 프로그램 시청시간을 합산하여 새로운 column(duration_sum)으로 지정하여 program_view_sum에 저장

# %%
program_view_sum = tidy_df.groupby(['일자', '패널가구ID', '개인ID', '프로그램명'])['duration'].sum().reset_index(name = 'duration_sum')

# %% [markdown]
# program_view_sum에서 일자별, 개인별로 시청한 프로그램 중 시청시간 threshold 이상인 것만 subset으로 filtered에 저장

# %%
filtered = program_view_sum[program_view_sum.duration_sum > datetime.timedelta(minutes = 15)]

# %%
type(program_view_sum)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# threshold 이상 시청한 프로그램을 대상으로 일자별, 개인별로 시청한 프로그램을 list 형태로 저장하고 daily_program_repertoire에 저장

# %%
daily_program_repertoire = filtered.groupby(['일자', '패널가구ID', '개인ID'])['프로그램명'].apply(list)
daily_program_repertoire.head(20)
# Out:
# 일자        패널가구ID   개인ID
# 20150817  1401639  aa      [가족을지켜라, 그래도푸르른날에, 나혼자산다, 베를린-2부, 벤자민버튼의시간은거꾸로...
#                    ab      [MBC뉴스데스크, 가족을지켜라, 그래도푸르른날에, 나혼자산다, 벤자민버튼의시간은거...
#           1401643  aa      [SBS월화드라마(미세스캅), 광복특별기획학교교육백년사, 달라졌어요, 생활의달인, ...
#           1401646  aa      [2TV저녁, 6시내고향, MBC뉴스데스크, SBS월화드라마(미세스캅), 우리말겨루...
#                    ab      [2TV저녁, 6시내고향, MBC뉴스데스크, SBS월화드라마(미세스캅), 우리말겨루...
#           1401694  aa                 [돌아온황금복, 스콜피온, 일일드라마(울지않는새<본>), 주말엔영화]
#                    ab      [2015메이저리그, 2015메이저리그<생>, 마지막황제, 미스터리음악쇼복면가왕, ...
#           1401699  aa      [JTBC뉴스룸, TV조선뉴스9, TV주치의닥터지바고<재>, 나는몸신이다<재>, 낭...
#           1401700  aa                             [생활의달인, 안녕하세요, 창사특별기획(화정)]
#                    ab                                   [KBS뉴스광장1부, 모닝와이드2부]
#                    ac      [JTBC뉴스현장, 금토드라마(오나의귀신님), 금토미니시리즈(라스트<재>), 도둑들...
#           1401710  aa      [곰디와친구들, 놀이터구조대뽀잉<재>, 두다다쿵<재>, 모닝와이드3부, 바오밥섬의파...
#           1401714  aa                                [그린실버고향이좋다, 내몸사용설명서<재>]
#                    ab        [MBC아침드라마(이브의사랑), 리얼스토리눈, 창사특별기획(화정), 힐링캠프500인]
#                    ac                             [국토대장정특집다큐청춘573.8KM길위에서꿈.]
#           1401718  ab      [5시정치부회의, MBC뉴스투데이2부, MBC뉴스투데이2부L, MBC아침드라마(이브...
#                    ac                                   [개구리중사케로로, 짱구는못말려15]
#           1401719  aa      [MBN뉴스8, SBS8뉴스, TV조선뉴스9, 냉장고를부탁해, 리얼극장아빠와사춘기,...
#                    ab      [KBS8아침뉴스타임, MBC5이브닝뉴스, MBC930생활뉴스, MBN뉴스8, SB...
#                    ac      [KBS8아침뉴스타임, MBC5이브닝뉴스, MBC930생활뉴스, MBN뉴스8, SB...
# Name: 프로그램명, dtype: object

# %%
lambda x: x[2], daily_program_repertoire
# Out:
# (<function __main__.<lambda>>, 일자        패널가구ID   개인ID
#  20150817  1401639  aa      [가족을지켜라, 그래도푸르른날에, 나혼자산다, 베를린-2부, 벤자민버튼의시간은거꾸로...
#                     ab      [MBC뉴스데스크, 가족을지켜라, 그래도푸르른날에, 나혼자산다, 벤자민버튼의시간은거...
#            1401643  aa      [SBS월화드라마(미세스캅), 광복특별기획학교교육백년사, 달라졌어요, 생활의달인, ...
#            1401646  aa      [2TV저녁, 6시내고향, MBC뉴스데스크, SBS월화드라마(미세스캅), 우리말겨루...
#                     ab      [2TV저녁, 6시내고향, MBC뉴스데스크, SBS월화드라마(미세스캅), 우리말겨루...
#            1401694  aa                 [돌아온황금복, 스콜피온, 일일드라마(울지않는새<본>), 주말엔영화]
#                     ab      [2015메이저리그, 2015메이저리그<생>, 마지막황제, 미스터리음악쇼복면가왕, ...
#            1401699  aa      [JTBC뉴스룸, TV조선뉴스9, TV주치의닥터지바고<재>, 나는몸신이다<재>, 낭...
#            1401700  aa                             [생활의달인, 안녕하세요, 창사특별기획(화정)]
#                     ab                                   [KBS뉴스광장1부, 모닝와이드2부]
#                     ac      [JTBC뉴스현장, 금토드라마(오나의귀신님), 금토미니시리즈(라스트<재>), 도둑들...
#            1401710  aa      [곰디와친구들, 놀이터구조대뽀잉<재>, 두다다쿵<재>, 모닝와이드3부, 바오밥섬의파...
#            1401714  aa                                [그린실버고향이좋다, 내몸사용설명서<재>]
#                     ab        [MBC아침드라마(이브의사랑), 리얼스토리눈, 창사특별기획(화정), 힐링캠프500인]
#                     ac                             [국토대장정특집다큐청춘573.8KM길위에서꿈.]
#            1401718  ab      [5시정치부회의, MBC뉴스투데이2부, MBC뉴스투데이2부L, MBC아침드라마(이브...
#                     ac                                   [개구리중사케로로, 짱구는못말려15]
#            1401719  aa      [MBN뉴스8, SBS8뉴스, TV조선뉴스9, 냉장고를부탁해, 리얼극장아빠와사춘기,...
#                     ab      [KBS8아침뉴스타임, MBC5이브닝뉴스, MBC930생활뉴스, MBN뉴스8, SB...
#                     ac      [KBS8아침뉴스타임, MBC5이브닝뉴스, MBC930생활뉴스, MBN뉴스8, SB...
#                     ad      [MBC5이브닝뉴스, MBN뉴스8, SBS8뉴스, 냉장고를부탁해, 리얼극장아빠와사춘...
#            1401721  aa      [2TV아침1부, 2TV아침2부, KBS뉴스(09:30), 김제동의톡투유걱정말아요그...
#                     ab      [4시사건반장, KBS뉴스(09:30), KBS뉴스9, TASTYROAD2015, ...
#                     ac      [4시사건반장, KBS뉴스9, TASTYROAD2015, TV주치의닥터지바고, 기분...
#            1401726  aa                                      [KBS뉴스12, 뉴스타워2부]
#                     ab      [2015프로야구<생>, 2TV저녁, 6시내고향, I러브베이스볼MINI, KBS뉴스...
#            1401728  ab      [KBS뉴스9, SBS8뉴스, SBS월화드라마(미세스캅), 삼시세끼정선편, 여행해도...
#            1401729  aa      [2TV저녁, KBS뉴스9, NEWS통, SBS월화드라마(미세스캅), 광복특집다큐(...
#                     ab      [KBS뉴스9, SBS월화드라마(미세스캅), 광복특집다큐(세계와함께코리아2부), 남...
#            1401731  ab      [KBS뉴스9, KBS뉴스광장1부, KBS뉴스광장2부, MBC뉴스데스크, SBSCN...
#                                                   ...
#  20150830  2403731  ab      [MBC뉴스데스크, 일밤, 일요일이좋다(아빠를부탁해,런닝맨), 주말드라마(여자를울려...
#                     ad      [MBC뉴스데스크, 일밤, 일요일이좋다(아빠를부탁해,런닝맨), 주말드라마(여자를울려...
#            2403735  ab                                               [SBS8뉴스]
#                     ac                                               [SBS8뉴스]
#                     ad                                               [SBS8뉴스]
#            2403736  aa      [2015메이저리그<생>, 금토드라마(두번째스무살), 남북소통버라이어티이제만나러갑니...
#                     ab      [남북소통버라이어티이제만나러갑니다, 별난며느리, 애정통일남남북녀2<재>, 일밤, 일...
#            2403738  aa      [KBS뉴스9, 개그콘서트, 광복70년특별기획KBS미래포럼북한의변화와., 냉장고를부...
#                     ab      [KBS뉴스9, 개그콘서트, 광복70년특별기획KBS미래포럼북한의변화와., 냉장고를부...
#            2403739  aa      [광복70년특집사랑하라대한민국, 슈퍼맨이돌아왔다, 어머님은내며느리, 일요일이좋다(아...
#                     ab      [MBC뉴스데스크, 광복70년특집사랑하라대한민국, 나혼자산다, 동상이몽괜찮아괜찮아,...
#                     ac      [MBC뉴스데스크, 광복70년특집사랑하라대한민국, 나혼자산다, 동상이몽괜찮아괜찮아,...
#            2403740  aa      [KBS뉴스9, KBS슈퍼클래식, SBS뉴스(12:00), SBS스페셜(가족끼리왜이...
#            2403741  aa                               [2015/2016잉글리시프리미어리그<생>]
#                     ab                                      [개그콘서트, 웃음을찾는사람들]
#                     ac       [개그콘서트, 검정고무신4, 섹션TV연예통신, 웃음을찾는사람들, 티미의못말리는수호천사]
#                     ad                                      [개그콘서트, 웃음을찾는사람들]
#            2403744  aa                                      [1박2일<재>, 출발드림팀2]
#                     ab                     [1박2일<재>, 개그콘서트, 출발드림팀2, 해피투게더스페셜]
#                     ad                        [섹션TV연예통신, 일밤, 해피선데이, 해피투게더스페셜]
#            2403745  aa                   [강적들<재>, 개그콘서트, 다큐3일, 닥터의승부, 슈퍼스타K7]
#                     ab                   [강적들<재>, 개그콘서트, 다큐3일, 닥터의승부, 슈퍼스타K7]
#            2403746  aa      [2015메이저리그, 2015메이저리그<생>, 2015이대호일본프로야구<생>, 20...
#                     ab      [KBS뉴스(06:00), KBS뉴스9, MBN뉴스와이드, TV회고록울림, WWER...
#            2403749  ab      [SBS스페셜(가족끼리왜이래부모의몫VS자식.), TV동물농장, 남북소통버라이어티이제...
#            2403751  aa      [2015프로야구H/L, 개그콘서트, 늘푸른인생, 다큐3일, 또봇탐험대카고와테라클,...
#                     ab      [개그콘서트, 네모바지스폰지밥, 다큐3일, 또봇탐험대카고와테라클, 라바인뉴욕, 바로...
#                     ac      [1박2일<재>, 2015프로야구H/L, 개그콘서트, 주말연속극(부탁해요엄마), 주...
#                     ad      [1박2일<재>, MBC뉴스데스크, 개그콘서트, 네모바지스폰지밥, 또봇탐험대카고와테...
#                     ae                   [또봇탐험대카고와테라클, 블레이징틴스레전드전사, 펭귄의문제비긴즈]
#  Name: 프로그램명, dtype: object)

# %%
# sample_repertoire = list(pd.DataFrame(daily_program_repertoire).ix['20150827', '1401639', 'aa'])

# %%
daily_program_repertoire.to_csv('output/output.csv')
