# %%
# %autosave 300
# Out:
# Autosaving every 300 seconds

# %%
# from Cleanser import get_data, convert_time
from functools import reduce
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import numpy as np
import seaborn as sns

# sns.set(color_codes=True)
matplotlib.style.use("ggplot")
# %matplotlib inline

# %%
tidy_df = pd.read_pickle('output/tidy_df.pkl')

# %%
tidy_df.shape
# Out:
# (2153476, 18)

# %%
prime = tidy_df[(tidy_df.시청시작시간.dt.hour >= 17) & (tidy_df.프로그램시청시간 >= 600)].copy()

# %%
# prime.groupby(['일자', 'ID', '프로그램명', '방송사', '대분류', '요일']).프로그램시청시간.apply(sum)
# Out:
# 일자        ID         프로그램명                      방송사           대분류      요일
# 20160822  1401861aa  KBS글로벌24                   KBS2          보도       Mon     1396
#                      생방송투데이                     SBS           정보       Mon     2400
#                      수상한휴가                      KBS2          오락       Mon     3465
#                      월화드라마(닥터스)                 SBS           드라마&영화   Mon     8089
#                      일일드라마(여자의비밀)               KBS2          드라마&영화   Mon     2298
#                      일일연속극(다시시작해)               MBC           드라마&영화   Mon     2166
#           1401861ab  KBS글로벌24                   KBS2          보도       Mon     1396
#                      생방송투데이                     SBS           정보       Mon     2400
#                      수상한휴가                      KBS2          오락       Mon     3465
#                      월화드라마(닥터스)                 SBS           드라마&영화   Mon     8089
#                      일일드라마(여자의비밀)               KBS2          드라마&영화   Mon     2298
#                      일일연속극(다시시작해)               MBC           드라마&영화   Mon     2166
#           1401900ab  비밀은없다이것은실화다                TV조선          드라마&영화   Mon     1740
#                      함정-1부                      OCN           드라마&영화   Mon     1080
#           1401900ac  무한도전                       MBC드라마넷       오락       Mon      623
#                      비밀은없다이것은실화다                TV조선          드라마&영화   Mon     1740
#                      함정-1부                      OCN           드라마&영화   Mon     1080
#                      황금어장라디오스타                  MBC드라마넷       오락       Mon     1830
#           1401908aa  2016KCC프로아마최강전<생>          MBC SPORTS+2  스포츠      Mon     1080
#                      김선영의뉴스나이트                  YTN           보도       Mon     2700
#                      리우2016메달리스트                SBS Sports    스포츠      Mon      600
#                      리우올림픽2016결산특집리우에서빛나다       KBS1          정보       Mon      900
#                      생방송투데이                     SBS           정보       Mon     1380
#                      생활의달인                      SBS           정보       Mon     2100
#                      투나잇23                      연합뉴스TV        보도       Mon     1020
#           1401908ab  김선영의뉴스나이트                  YTN           보도       Mon     2700
#                      리우올림픽2016결산특집리우에서빛나다       KBS1          정보       Mon      900
#                      투나잇23                      연합뉴스TV        보도       Mon     1020
#           1401909aa  KBS뉴스9                     KBS1          보도       Mon     2220
#                      MBN뉴스8                     MBN           보도       Mon     1620
#                                                                               ...
# 20170122  2404333aa  시사스페셜                      MBN           보도       Sun     1786
#                      안녕자두야3                     Tooniverse    어린이(유아)  Sun      900
#                      주말연속극(월계수양복점신사들)           KBS2          드라마&영화   Sun     4200
#           2404333ab  KBS뉴스9                     KBS1          보도       Sun     1800
#                      MBN뉴스와이드                   MBN           보도       Sun     3944
#                      시사스페셜                      MBN           보도       Sun     1786
#                      안녕자두야3                     Tooniverse    어린이(유아)  Sun      900
#                      주말연속극(월계수양복점신사들)           KBS2          드라마&영화   Sun     4200
#           2404334ab  MBN뉴스와이드                   MBN           보도       Sun     5825
#                      김제동의톡투유걱정말아요그대             JTBC          오락       Sun     1947
#                      놓치지말아야할소리보이스               tvN           드라마&영화   Sun     4338
#                      뇌섹시대문제적남자<본>               tvN           오락       Sun     3947
#                      시사스페셜                      MBN           보도       Sun     1546
#                      이규연의스포트라이트                 JTBC          보도       Sun     3245
#                      주말드라마(불어라미풍아)              MBC           드라마&영화   Sun     2640
#                      주말연속극(월계수양복점신사들)           KBS2          드라마&영화   Sun     4306
#                      해피선데이                      KBS2          오락       Sun     1141
#           2404337aa  SBS8뉴스                     SBS           보도       Sun      780
#           2404337ab  SBS8뉴스                     SBS           보도       Sun     2040
#                      김제동의톡투유걱정말아요그대             JTBC          오락       Sun     3840
#                      세상에나쁜개는없다                  skyPetpark    정보       Sun      960
#                      이규연의스포트라이트                 JTBC          보도       Sun     2640
#                      일밤1부                       MBC           오락       Sun     5220
#           2404345aa  2017유러피언투어아부다비HSBC챔피언십<생>  JTBC GOLF     스포츠      Sun    14040
#                      K팝스타더라스트찬스                 SBS           오락       Sun     5100
#                      TV조선뉴스현장                   TV조선          보도       Sun     1200
#                      이제만나러갑니다                   채널A           오락       Sun      840
#           2404345ab  2017유러피언투어아부다비HSBC챔피언십<생>  JTBC GOLF     스포츠      Sun    14040
#                      K팝스타더라스트찬스                 SBS           오락       Sun     5100
#                      TV조선뉴스현장                   TV조선          보도       Sun     1200
# Name: 프로그램시청시간, dtype: int64

# %%
temp = prime.groupby(['기간', '일자', 'ID']).agg({'시청시작시간' : min,
                               '시청종료시간' : max})

# %%
ids = tidy_df.groupby('기간').ID.apply(set).reset_index().set_index('기간')
target_audience = list(ids.ID[0] & ids.ID[1] & ids.ID[2])

# %%
temp['진입시간대'] = temp.시청시작시간.dt.hour
temp['이탈시간대'] = temp.시청종료시간.dt.hour

# %%
temp.이탈시간대.replace({0:24, 1:25, 2:26, 3:27}, inplace=True)
temp.진입시간대.replace({0:24, 1:25, 2:26, 3:27}, inplace=True)

# %%
temp['종단'] = list(zip(temp.진입시간대, temp.이탈시간대))

# %%
agg1 = {
    '프로그램시청시간' : {
        '시청비율' : 'sum'
    }
}

# %%
genre_ratio = prime.groupby(['ID','기간','일자','대분류'])\
    .agg(agg1).groupby(level=[0,1,2]).apply(lambda x: x/float(x.sum()))

# Flattening hierarchical columns
genre_ratio.columns = genre_ratio.columns.get_level_values(1)

# %%
gr_pivot = pd.pivot_table(genre_ratio.reset_index(), 
                          values = '시청비율', 
                          index = ['기간', '일자', 'ID'], 
                          columns = '대분류').replace(np.nan, 0)

# %%
raw_data = gr_pivot.join(temp[['진입시간대','이탈시간대']])

# %%
from sklearn.cluster import DBSCAN, KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.datasets.samples_generator import make_blobs
from sklearn import metrics

# %%
X = StandardScaler().fit_transform(raw_data)
Y = MinMaxScaler().fit_transform(raw_data)

# %%
raw_data.values[:1000:200]
# Out:
# array([[  0.        ,   0.        ,   0.63354194,   0.07045523,
#           0.        ,   0.        ,   0.17487635,   0.12112648,
#          18.        ,  24.        ],
#        [  0.        ,   0.        ,   0.48558067,   0.51441933,
#           0.        ,   0.        ,   0.        ,   0.        ,
#          19.        ,  20.        ],
#        [  0.        ,   0.        ,   0.32351433,   0.29200615,
#           0.        ,   0.        ,   0.20300838,   0.18147114,
#          17.        ,  23.        ],
#        [  0.        ,   0.        ,   0.48943776,   0.40192209,
#           0.10864014,   0.        ,   0.        ,   0.        ,
#          17.        ,  24.        ],
#        [  0.        ,   0.        ,   0.35107994,   0.24712482,
#           0.        ,   0.        ,   0.1258345 ,   0.27596073,
#          17.        ,  22.        ]])

# %%
Y[:1000:200]
# Out:
# array([[ 0.        ,  0.        ,  0.63354194,  0.07045523,  0.        ,
#          0.        ,  0.17487635,  0.12112648,  0.16666667,  0.875     ],
#        [ 0.        ,  0.        ,  0.48558067,  0.51441933,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.33333333,  0.375     ],
#        [ 0.        ,  0.        ,  0.32351433,  0.29200615,  0.        ,
#          0.        ,  0.20300838,  0.18147114,  0.        ,  0.75      ],
#        [ 0.        ,  0.        ,  0.48943776,  0.40192209,  0.10864014,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.875     ],
#        [ 0.        ,  0.        ,  0.35107994,  0.24712482,  0.        ,
#          0.        ,  0.1258345 ,  0.27596073,  0.        ,  0.625     ]])

# %%
X[:1000:200]
# Out:
# array([[-0.0697975 , -0.03608529,  1.12462971, -0.51870061, -0.27293076,
#         -0.19712155, -0.40881507, -0.00849366, -0.51613291,  0.86637645],
#        [-0.0697975 , -0.03608529,  0.63206259,  1.17097584, -0.27293076,
#         -0.19712155, -0.9646446 , -0.61094984,  0.03741937, -1.51363624],
#        [-0.0697975 , -0.03608529,  0.0925393 ,  0.32449679, -0.27293076,
#         -0.19712155, -0.31939983,  0.2916473 , -1.06968519,  0.27137328],
#        [-0.0697975 , -0.03608529,  0.64490296,  0.74282426,  0.44241847,
#         -0.19712155, -0.9646446 , -0.61094984, -1.06968519,  0.86637645],
#        [-0.0697975 , -0.03608529,  0.18430599,  0.1536836 , -0.27293076,
#         -0.19712155, -0.56469039,  0.76161752, -1.06968519, -0.3236299 ]])

# %%
pd.DataFrame(Y).describe()
# Out:
#                   0             1             2             3             4  \
# count  89632.000000  89632.000000  89632.000000  89632.000000  89632.000000
# mean       0.001409      0.000444      0.295717      0.206744      0.041450
# std        0.020194      0.012294      0.300390      0.262752      0.151871
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.239489      0.110563      0.000000
# 75%        0.000000      0.000000      0.488736      0.325288      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                   5             6             7             8             9
# count  89632.000000  89632.000000  89632.000000  89632.000000  89632.000000
# mean       0.027903      0.303499      0.122834      0.322067      0.692989
# std        0.141554      0.314624      0.201056      0.301087      0.210084
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.625000
# 50%        0.000000      0.229024      0.000000      0.333333      0.750000
# 75%        0.000000      0.502341      0.192333      0.500000      0.875000
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
eps=0.5
min_samples=50

# %%
dbx = DBSCAN(eps=eps, min_samples=min_samples).fit(X)

# %%
dby = DBSCAN(eps=0.1, min_samples=30).fit(Y)

# %%
import pickle

# now you can save it to a file
with open('output/standard_eps%s_min%s.pkl' % (eps, min_samples), 'wb') as f:
    pickle.dump(dbx, f)

with open('output/minmax_eps%s_min%s.pkl' % (eps, min_samples), 'wb') as f:
    pickle.dump(dby, f)

# %%
# and later you can load it
with open('filename.pkl', 'rb') as f:
    clf = pickle.load(f)

# %%
ylabels=dby.labels_

# %%
np.bincount(ylabels + 1)
# Out:
# array([33038,  3172,   102,   440,   399,    95,   221,   272,  2829,
#          306,  5806,  2056,  4410,   435,   140,  1480,   371,   239,
#          139,  1511,   160,  2359,   334,  1861,   138,   353,   305,
#           64,   128,   357,  1197,   394,  2707,   101,    42,   116,
#          101,   183,   153,   322,    52,   107,   174,   284,  1208,
#           39,   444,    55,    78,   129,   260,    63,   176,   138,
#           87,   204,    92,    79,   201,    88,    46,    33,   478,
#           49,  1351,   271,    79,    68,    55,   104,    68,   116,
#          278,   220,   100,    96,   113,   314,    68,   239,   100,
#           31,   650,   357,   184,   546,   119,    91,   154,    50,
#           33,    55,    62,    35,    70,   284,   882,   124,   104,
#           40,    56,    63,   128,    36,   323,    71,    73,    60,
#           87,    75,    57,    68,   110,   168,   313,    49,    39,
#          104,    76,    38,   157,    75,    21,   133,    40,    77,
#           41,    92,   111,    80,    91,    67,    89,    86,    38,
#           66,   133,    82,    36,    53,    81,   173,    43,    62,
#           65,    37,    30,    33,    44,   132,    62,   300,   148,
#           53,    75,    41,    50,    50,   175,    32,   115,    74,
#           47,    33,    31,    34,    41,   431,    51,    37,    33,
#          115,    32,    45,    42,    51,    30,    51,    95,    50,
#           66,    36,   185,    58,    48,    44,    54,    37,    75,
#           44,    59,    40,    84,    44,    45,    40,    45,    40,
#           34,    34,    37,    29,    43,    43,    45,    40,    21,
#           36,    47,    30,    35,    31,    30,    24,    30,    30,
#           29,    24,    30,    16,    41,    30,    24,    30,    12,
#           26,    26,    24,    31,    29], dtype=int64)

# %%
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

# %%
n_clusters_
# Out:
# 128

# %%
np.bincount(labels + 1)
# Out:
# array([32402,  3521,   102,   440,   431,    95,   221,   272,  3000,
#          306,  5863,  2125,  4814,  1143,   140,  2125,   371,   239,
#          139,  1709,   282,  2560,   839,  1890,   138,  1961,   314,
#           64,   104,   488,   357,  1823,   394,  3031,   116,   101,
#          183,   322,    52,   107,   174,   284,  1208,   620,    78,
#          133,   260,    63,   176,   116,   138,    87,    92,    95,
#           83,  1351,   316,    86,    93,   117,    68,   116,   220,
#          213,    96,   314,    68,   239,   100,   739,   184,   546,
#          119,    91,    58,    65,    70,   124,   104,    56,    76,
#          128,   323,    71,    73,    57,    68,   110,   225,   313,
#           98,   157,    89,   171,   121,   130,    80,    91,    89,
#           86,   133,   173,    62,    65,   157,   509,   377,    50,
#          203,   133,   263,    71,   118,   113,    62,    46,    51,
#           66,    61,    95,    28,    75,    88,    75,    65,    69,
#           52,    19,    53], dtype=int64)

# %%
raw_data[ylabels == 10].describe()
# Out:
#                 교육           기타       드라마&영화           보도          스포츠  \
# count  2056.000000  2056.000000  2056.000000  2056.000000  2056.000000
# mean      0.000069     0.000068     0.378240     0.142969     0.002129
# std       0.001796     0.001773     0.263174     0.151615     0.012488
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.201752     0.000000     0.000000
# 50%       0.000000     0.000000     0.336633     0.099335     0.000000
# 75%       0.000000     0.000000     0.560400     0.257102     0.000000
# max       0.047040     0.052200     1.000000     0.592471     0.126506
#
#            어린이(유아)           오락           정보   진입시간대   이탈시간대
# count  2056.000000  2056.000000  2056.000000  2056.0  2056.0
# mean      0.000302     0.443274     0.032949    20.0    24.0
# std       0.005154     0.263278     0.069548     0.0     0.0
# min       0.000000     0.000000     0.000000    20.0    24.0
# 25%       0.000000     0.272607     0.000000    20.0    24.0
# 50%       0.000000     0.413919     0.000000    20.0    24.0
# 75%       0.000000     0.632226     0.000000    20.0    24.0
# max       0.121704     1.000000     0.369383    20.0    24.0

# %%
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
for k, col in zip(unique_labels, colors):
    print(k,col)
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# 0 [ 0.61960784  0.00392157  0.25882353  1.        ]
# 1 [ 0.63652441  0.02268358  0.26282199  1.        ]
# 2 [ 0.65344098  0.0414456   0.26682045  1.        ]
# 3 [ 0.67035755  0.06020761  0.27081892  1.        ]
# 4 [ 0.68727413  0.07896963  0.27481738  1.        ]
# 5 [ 0.7041907   0.09773164  0.27881584  1.        ]
# 6 [ 0.72110727  0.11649366  0.2828143   1.        ]
# 7 [ 0.73802384  0.13525567  0.28681276  1.        ]
# 8 [ 0.75494041  0.15401769  0.29081123  1.        ]
# 9 [ 0.77185698  0.1727797   0.29480969  1.        ]
# 10 [ 0.78877355  0.19154171  0.29880815  1.        ]
# 11 [ 0.80569012  0.21030373  0.30280661  1.        ]
# 12 [ 0.82260669  0.22906574  0.30680507  1.        ]
# 13 [ 0.83767782  0.24675125  0.3088812   1.        ]
# 14 [ 0.84721261  0.26120723  0.30519031  1.        ]
# 15 [ 0.8567474   0.27566321  0.30149942  1.        ]
# 16 [ 0.8662822   0.29011918  0.29780854  1.        ]
# 17 [ 0.87581699  0.30457516  0.29411765  1.        ]
# 18 [ 0.88535179  0.31903114  0.29042676  1.        ]
# 19 [ 0.89488658  0.33348712  0.28673587  1.        ]
# 20 [ 0.90442138  0.3479431   0.28304498  1.        ]
# 21 [ 0.91395617  0.36239908  0.27935409  1.        ]
# 22 [ 0.92349097  0.37685506  0.27566321  1.        ]
# 23 [ 0.93302576  0.39131103  0.27197232  1.        ]
# 24 [ 0.94256055  0.40576701  0.26828143  1.        ]
# 25 [ 0.95209535  0.42022299  0.26459054  1.        ]
# 26 [ 0.95824683  0.43744714  0.26735871  1.        ]
# 27 [ 0.96101499  0.45743945  0.27658593  1.        ]
# 28 [ 0.96378316  0.47743176  0.28581315  1.        ]
# 29 [ 0.96655133  0.49742407  0.29504037  1.        ]
# 30 [ 0.96931949  0.51741638  0.30426759  1.        ]
# 31 [ 0.97208766  0.53740869  0.31349481  1.        ]
# 32 [ 0.97485582  0.557401    0.32272203  1.        ]
# 33 [ 0.97762399  0.57739331  0.33194925  1.        ]
# 34 [ 0.98039216  0.59738562  0.34117647  1.        ]
# 35 [ 0.98316032  0.61737793  0.35040369  1.        ]
# 36 [ 0.98592849  0.63737024  0.35963091  1.        ]
# 37 [ 0.98869666  0.65736255  0.36885813  1.        ]

# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-9979c7108a1e> in <module>()
#       3 centroids = [k.cluster_centers_ for k in KM]
#       4
# ----> 5 D_k = [cdist(dt_trans, cent, 'euclidean') for cent in centroids]
#       6 cIdx = [np.argmin(D,axis=1) for D in D_k]
#       7 dist = [np.min(D,axis=1) for D in D_k]
#
# <ipython-input-88-9979c7108a1e> in <listcomp>(.0)
#       3 centroids = [k.cluster_centers_ for k in KM]
#       4
# ----> 5 D_k = [cdist(dt_trans, cent, 'euclidean') for cent in centroids]
#       6 cIdx = [np.argmin(D,axis=1) for D in D_k]
#       7 dist = [np.min(D,axis=1) for D in D_k]
#
# NameError: name 'cdist' is not defined

# %%
D_k = [cdist(dt_trans, cent, 'euclidean') for cent in centroids]
cIdx = [np.argmin(D,axis=1) for D in D_k]
dist = [np.min(D,axis=1) for D in D_k]
avgWithinSS = [sum(d)/dt_trans.shape[0] for d in dist]

# %%
# elbow curve
kIdx = 10
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(K, avgWithinSS, 'b*-')
ax.plot(K[kIdx], avgWithinSS[kIdx], marker='o', markersize=12, 
markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Average within-cluster sum of squares')
plt.title('Elbow for KMeans clustering')

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(dt_trans, labels, metric='euclidean', sample_size=10000)
# Out:
# 0.18714792735174807

# %%
from sklearn.metrics import silhouette_score

s = []
for n_clusters in range(2,30):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(dt_trans)

    labels = kmeans.labels_
    centroids = kmeans.cluster_centers_

    s.append(silhouette_score(dt_trans, labels, metric='euclidean', sample_size=10000))

# %%
plt.plot(s)
plt.plot(K[kIdx-2], s[kIdx-1], marker='o', markersize=12, 
markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.ylabel("Silouette")
plt.xlabel("k")
plt.title("Silouette for K-means cell's behaviour")
sns.despine()

# %%
raw_data[KM[10].labels_ == 4]
# Out:
#                              교육   기타    드라마&영화        보도       스포츠  어린이(유아)  \
# 기간 일자       ID
# T2 20160822 1401927aa  0.000000  0.0  0.040166  0.401664  0.000000  0.29135
#             1401927ab  0.000000  0.0  0.040166  0.401664  0.000000  0.29135
#             1401929ab  0.000000  0.0  0.350951  0.215645  0.000000  0.00000
#             1401929ac  0.000000  0.0  0.350951  0.215645  0.000000  0.00000
#             1401937ab  0.000000  0.0  0.161532  0.356976  0.000000  0.00000
#             1401965aa  0.000000  0.0  0.302046  0.324910  0.180505  0.00000
#             1401972aa  0.000000  0.0  0.376149  0.221402  0.000000  0.00000
#             1401972ab  0.000000  0.0  0.376149  0.221402  0.000000  0.00000
#             1401973aa  0.000000  0.0  0.396656  0.280022  0.000000  0.00000
#             1402004aa  0.000000  0.0  0.125809  0.308465  0.000000  0.00000
#             1402004ab  0.000000  0.0  0.230468  0.319695  0.000000  0.00000
#             1402020aa  0.000000  0.0  0.472547  0.311491  0.000000  0.00000
#             1402038aa  0.000000  0.0  0.053010  0.307523  0.000000  0.00000
#             1402050aa  0.000000  0.0  0.202073  0.424870  0.000000  0.00000
#             1402050ab  0.000000  0.0  0.260000  0.346667  0.000000  0.00000
#             1402072ab  0.000000  0.0  0.000000  0.457447  0.000000  0.00000
#             1402073ab  0.000000  0.0  0.311426  0.425080  0.000000  0.00000
#             1402073ac  0.000000  0.0  0.373408  0.310655  0.000000  0.00000
#             1402073ad  0.000000  0.0  0.311426  0.425080  0.000000  0.00000
#             1402074aa  0.000000  0.0  0.375436  0.331444  0.000000  0.00000
#             1401927ab  0.170468  0.096352     17     23
#             1401929ab  0.188865  0.244538     19     24
#             1401929ac  0.188865  0.244538     19     24
#             1401937ab  0.481491  0.000000     17     24
#             1401965aa  0.132371  0.060168     18     23
#             1401972aa  0.239794  0.162654     17     23
#             1401972ab  0.239794  0.162654     17     23
#             1401973aa  0.030492  0.292829     17     24
#             1402004aa  0.327057  0.238669     18     24
#             1402004ab  0.318172  0.131665     18     21
#             1402020aa  0.215963  0.000000     19     24
#             1402038aa  0.490634  0.148833     17     25
#             1402050aa  0.305699  0.067358     20     24
#             1402050ab  0.393333  0.000000     20     23
#             1402072ab  0.542553  0.000000     19     22
#             1402073ab  0.263494  0.000000     19     23
#             1402073ac  0.315937  0.000000     19     23
#             1402073ad  0.263494  0.000000     19     23
#             1402074aa  0.138435  0.154685     18     25
#             1402074ab  0.158881  0.029839     19     25
#             1402083aa  0.324366  0.202113     17     22
#             1402097ab  0.388272  0.172962     17     22
#             1402099aa  0.711858  0.000000     19     24
#             1402112ac  0.645418  0.000000     19     24
#             1402119ab  0.382117  0.246196     17     24
#             1402147aa  0.245452  0.258804     17     22
#             1402147ab  0.384475  0.000000     19     22
#             1402157aa  0.398614  0.285962     17     22
#             1402157ab  0.398614  0.285962     17     22
# ...                         ...       ...    ...    ...
# T4 20170122 2404215aa  0.765105  0.000000     17     23
#             2404218aa  0.760653  0.000000     17     25
#             2404223ab  0.566960  0.000000     18     24
#             2404234ab  0.315436  0.000000     20     23
#             2404237ab  0.455488  0.211019     19     24
#             2404239aa  0.805441  0.109403     18     24
#             2404239ab  0.805441  0.109403     18     24
#             2404240aa  0.623231  0.000000     19     23
#             2404242ab  0.542056  0.000000     19     23
#             2404250aa  0.898767  0.000000     17     24
#             2404259aa  0.410307  0.201922     17     25
#             2404259ab  0.410307  0.201922     17     25
#             2404265ab  0.630057  0.000000     19     23
#             2404269ab  0.400201  0.168325     19     23
#             2404270aa  0.338677  0.000000     18     24
#             2404270ab  0.338677  0.000000     18     24
#             2404275ab  0.332723  0.034719     17     24
#             2404277ab  0.615331  0.000000     19     23
#             2404280ab  0.323507  0.262692     19     25
#             2404300aa  0.371875  0.084375     17     23
#             2404300ab  0.371875  0.084375     17     23
#             2404303aa  0.501143  0.085901     18     25
#             2404312aa  0.337284  0.343704     18     24
#             2404314aa  0.519552  0.336977     18     23
#             2404323aa  0.205387  0.232411     20     24
#             2404324aa  0.546113  0.185595     17     23
#             2404325aa  0.583607  0.000000     18     23
#             2404325ab  0.583607  0.000000     18     23
#             2404334ab  0.243131  0.000000     17     25
#             2404337ab  0.616327  0.065306     17     24
#
# [21170 rows x 10 columns]

# %% [markdown]
# # TVPro2Vec

# %%
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO )

# %%
tidy = tidy_df[tidy_df.프로그램시청시간  >= 600].copy()

# %%
programs = tidy.groupby(['ID','일자']).프로그램명.apply(lambda x: ' '.join(x).split()).reset_index().프로그램명.tolist()

# %%
len(programs)

# %%
# model = gensim.models.Word2Vec(programs, min_count=1)
model = word2vec.Word2Vec(programs, size=300, window=10, min_count=5, workers=8)

# %%
model.most_similar(positive=['JTBC뉴스룸'], topn=20)
